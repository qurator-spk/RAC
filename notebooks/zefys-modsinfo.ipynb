# %%
import pandas as pd

# %%
df = pd.read_parquet('../workbench/mods_info.parquet')
df.shape
# Out:
# (351162, 30)

# %%
df.head(1130000).tail()
# Out:
#                  genre-marcgt language_languageTerm  \
# recordIdentifier
# 24319697          [newspaper]                 [ger]
# 24319697          [newspaper]                 [ger]
# 24319697          [newspaper]                 [ger]
# 24319697          [newspaper]                 [ger]
# 24319697          [newspaper]                 [ger]
#
#                  originInfo-publication0_dateIssued  \
# recordIdentifier
# 24319697                                 1908-01-10
# 24319697                                 1908-01-29
# 24319697                                 1908-01-07
# 24319697                                 1908-01-31
# 24319697                                 1908-03-01
#
#                  originInfo-publication0_edition  \
# recordIdentifier
# 24319697                            Hauptausgabe
# 24319697                            Hauptausgabe
# 24319697                            Hauptausgabe
# 24319697                            Hauptausgabe
# ...

# %%
df.columns
# Out:
# Index(['genre-marcgt', 'language_languageTerm',
#        'originInfo-publication0_dateIssued', 'originInfo-publication0_edition',
#        'originInfo-publication0_place_placeTerm',
#        'relatedItem-host_recordInfo_recordIdentifier',
#        'relatedItem-host_titleInfo_partName',
#        'relatedItem-host_titleInfo_subTitle',
#        'relatedItem-host_titleInfo_title', 'titleInfo_partName',
#        'titleInfo_subTitle', 'titleInfo_title', 'typeOfResource',
#        'mets_fileSec_fileGrp-DEFAULT-count', 'mets_fileSec_fileGrp-MAX-count',
#        'mets_fileSec_fileGrp-MIN-count', 'mets_fileSec_fileGrp-THUMBS-count',
#        'mets_fileSec_fileGrp-PRESENTATION-count',
#        'mets_fileSec_fileGrp-LOCAL-count',
#        'mets_fileSec_fileGrp-DOWNLOAD-count', 'mets_file', 'identifier-local',
#        'mets_fileSec_fileGrp-Images-count',
#        'mets_fileSec_fileGrp-Black and white version of images-count',
# ...

# %%
df['mets_fileSec_fileGrp-PRESENTATION-count'].sum()
# Out:
# np.int64(2955085)

# %%
df.titleInfo_title.value_counts()[0:40]
# Out:
# titleInfo_title
# Berliner Börsen-Zeitung                                                        36752
# Berliner Tageblatt und Handels-Zeitung                                         35975
# Norddeutsche allgemeine Zeitung                                                32620
# Berliner Volkszeitung                                                          32132
# Berliner Zeitung                                                               29578
# Neue Zeit                                                                      15598
# Neues Deutschland                                                              15493
# Deutsche allgemeine Zeitung                                                    11306
# Volkszeitung                                                                    9868
# Teltower Kreisblatt                                                             7602
# Deutsches Nachrichtenbüro                                                       7430
# ...

# %%
df['originInfo-publication0_place_placeTerm'].value_counts()
# Out:
# originInfo-publication0_place_placeTerm
# Kairo      289554
# Berlin        543
# Stettin       380
# Name: count, dtype: int64

# %%
df['mets_fileSec_fileGrp-PRESENTATION-count']
# Out:
# recordIdentifier
# 24350382    10
# 24350382     8
# 24350382     8
# 24350382     6
# 24350382     8
#             ..
# 24319697    10
# 24319697     8
# 24319697     8
# 24319697    10
# 24319697    14
# Name: mets_fileSec_fileGrp-PRESENTATION-count, Length: 351162, dtype: Int64
